# %% [markdown]
# <a href="https://colab.research.google.com/github/baussel/Satellite_Detection/blob/main/FITS_file.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
# %matplotlib inline 
import numpy as np

# %%
from astropy.io import fits

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
image_file = "drive/MyDrive/ESA/Data/Test/ict903auq_raw.fits"
fits.info(image_file)
# Out:
# Filename: drive/MyDrive/ESA/Data/Test/ict903auq_raw.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     240   ()
#   1  SCI           1 ImageHDU        92   (512, 512)   int16 (rescales to uint16)
#   2  ERR           1 ImageHDU        44   ()
#   3  DQ            1 ImageHDU        38   ()

# %%
image_data = fits.getdata(image_file, ext=1)
print(image_data.shape)
print(image_data)
# Out:
# (512, 512)
# [[32867 32779 32743 ...  2532  2533  2541]
#  [32906 33439 32715 ...  2541  2535  2538]
#  [32433 32603 32745 ...  2549  2548  2544]
#  ...
#  [ 2583  2560  2571 ... 48323 48286 48366]
#  [ 2571  2574  2573 ... 47633 47653 47704]
#  [ 2595  2588  2597 ... 13347 13964 14992]]

# %%
plt.imshow(image_data,cmap="gray")
plt.colorbar()

# %%
header_data = fits.getheader(image_file,ext=1)
print(header_data["DEC_APER"])
# Out:
# -17.84985809069
